# %% [markdown]
# ## Data Analytics II

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
df = pd.read_csv("Social_Network_Ads.csv")

df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.shape
# Out:
# (400, 3)

# %% [markdown]
# ## Separate Features & Target

# %%
X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %% [markdown]
# ## Feature Scaling

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Logistic Regression Model

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Make Predictions

# %%
y_pred = model.predict(X_test)

y_pred[:10]
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 1, 0, 1])

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[65,  3],
#        [ 8, 24]])

# %% [markdown]
# ## Performance Metrics

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

accuracy = accuracy_score(y_test, y_pred)
error_rate = 1 - accuracy
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

TP, FP, TN, FN, accuracy, error_rate, precision, recall
# Out:
# (np.int64(24),
#  np.int64(3),
#  np.int64(65),
#  np.int64(8),
#  0.89,
#  0.10999999999999999,
#  0.8888888888888888,
#  0.75)

# %% [markdown]
# ## Data Distribution

# %%
plt.scatter(df['Age'], df['EstimatedSalary'], c=df['Purchased'])
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.title("User Purchase Distribution")
plt.show()

# %% [markdown]
# ## Decision Boundary

# %%
from matplotlib.colors import ListedColormap

X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(
    np.arange(X_set[:, 0].min()-1, X_set[:, 0].max()+1, 0.01),
    np.arange(X_set[:, 1].min()-1, X_set[:, 1].max()+1, 0.01)
)

plt.contourf(X1, X2, model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape), alpha=0.3)

plt.scatter(X_set[:,0], X_set[:,1], c=y_set)
plt.xlabel("Age (scaled)")
plt.ylabel("Salary (scaled)")
plt.title("Logistic Regression Decision Boundary")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [raw]
# Logistic Regression was successfully implemented on Social Network Ads dataset to classify user purchase behavior.
# The confusion matrix was used to calculate TP, FP, TN, FN, Accuracy, Error Rate, Precision and Recall.
# The model achieved high accuracy and the decision boundary clearly separated purchase classes.
