# %% [markdown]
# ## Data Analytics III

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
df = pd.read_csv("Iris.csv")

df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# ## Separate Features & Target

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0
)

# %% [markdown]
# ## Apply Naïve Bayes (Gaussian)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Make Predictions

# %%
y_pred = model.predict(X_test)

y_pred[:10]
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor'],
#       dtype='<U15')

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  0, 11]])

# %% [markdown]
# ## Compute TP, FP, TN, FN

# %%
TP = cm[0,0]
FP = cm[:,0].sum() - TP
FN = cm[0,:].sum() - TP
TN = cm.sum() - (TP + FP + FN)

TP, FP, TN, FN
# Out:
# (np.int64(16), np.int64(0), np.int64(29), np.int64(0))

# %% [markdown]
# ## Performance Metrics

# %%
accuracy = accuracy_score(y_test, y_pred)
error_rate = 1 - accuracy
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')

accuracy, error_rate, precision, recall
# Out:
# (1.0, 0.0, 1.0, 1.0)

# %% [markdown]
# ## Data Distribution

# %%
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'], c=pd.factorize(df['Species'])[0])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Iris Data Distribution")
plt.show()

# %% [markdown]
# ## Confusion Matrix Heatmap

# %%
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [raw]
# The Naïve Bayes classifier was successfully implemented on the Iris dataset.
# The confusion matrix was used to calculate TP, FP, TN, FN, Accuracy, Error Rate, Precision and Recall.
# The model achieved high accuracy (around 97%), showing effective classification performance.
